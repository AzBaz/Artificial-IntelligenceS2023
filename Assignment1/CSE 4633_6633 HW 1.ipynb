# %% [markdown]
# # CSE 4633/6633 HW 1
#
# The assignment for this notebook is to implement local search algorithms such as hill-climbing, random restart, and simulated annealing to perform function optimization.

# %%
# import required libraries
import time
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
# Create a complex objective function that we need to maximize.
# Here, the objective function is simply defined as an equation but
# more generally, it could represent natural phenomena, physical laws, or mathematical models
#   X: a 2-dimensional floating-point vector consisting of an x-value and a y-value
#   returns: a scalar floating-point value representing the output of the objective function
def objective_function(X):
    x = X[0]
    y = X[1]
    value = 3 * (1 - x) ** 2 * math.exp(-x ** 2 - (y + 1) ** 2) - 10 * (x / 5 - x ** 3 - y ** 5) * math.exp(
        -x ** 2 - y ** 2) - (1 / 3) * math.exp(-(x + 1) ** 2 - y ** 2)
    return value

# to limit the search space for this problem, we will only consider solutions
# where x ranges from -4 to 4 and y ranges from -4 to 4
lower_bounds = [-4, -4]
upper_bounds = [4, 4]

# %% [markdown]
# A 3D plot of the objective function can be viewed [here](https://c3d.libretexts.org/CalcPlot3D/index.html?type=z;z=3(1-x)%5E2*exp(-x%5E2-(y+1)%5E2)-10(x/5-x%5E3-y%5E5)*exp(-x%5E2-y%5E2)-(1/3)*exp(-(x+1)%5E2-y%5E2);visible=true;umin=-4;umax=4;vmin=-4;vmax=4;grid=30;format=normal;alpha=-1;hidemyedges=true;constcol=rgb(255,0,0);view=0;contourcolor=red;fixdomain=false;contourplot=true;showcontourplot=false;firstvalue=-1;stepsize=0.2;numlevels=11;list=;uselist=false;xnum=46;ynum=46;show2d=false;hidesurface=false;hidelabels=true;showprojections=false;surfacecontours=true;projectioncolor=rgba(255,0,0,1);showxygrid=false;showxygridonbox=false;showconstraint=false&type=window;hsrmode=3;nomidpts=true;anaglyph=-1;center=-5.2487653277286155,6.815843602039553,5.098503557610455,1;focus=0,0,0,1;up=0.39284920127083023,-0.3373981166615778,0.8554718089651412,1;transparent=false;alpha=140;twoviews=false;unlinkviews=false;axisextension=0.7;xaxislabel=x;yaxislabel=y;zaxislabel=z;edgeson=true;faceson=true;showbox=true;showaxes=true;showticks=true;perspective=true;centerxpercent=0.5;centerypercent=0.5;rotationsteps=30;autospin=true;xygrid=false;yzgrid=false;xzgrid=false;gridsonbox=true;gridplanes=false;gridcolor=rgb(128,128,128);xmin=-4;xmax=4;ymin=-4;ymax=4;zmin=-4;zmax=4;xscale=2;yscale=2;zscale=2;zcmin=-8;zcmax=8;xscalefactor=1;yscalefactor=1;zscalefactor=1;tracemode=0;keep2d=false;zoom=0.89)

# %%
# Let's try to randomly generate several random inputs to the objective function
# and manually observe how the outputs change with different inputs

X = np.random.uniform(lower_bounds, upper_bounds)
value = objective_function(X)
print('objective_function(%.3f, %.3f) = %.3f' % (X[0], X[1], value))
# Out:
# objective_function(0.593, -3.881) = -0.002

# %% [markdown]
# # Part A: Hill-climbing

# %%
# TODO: Hill-climbing search algorithm: a loop that continually moves in the direction of increasing value.
# It terminates when it reaches a “peak” where no neighbor has a higher value.
#   objective function: function to be maximized
#   initial_state: initial (x, y) vector
#   step_size: numerical interval by which to change the current (x,y) state to generate a new neighboring state
#   print_iters: set to True to print out the current value at each iteration
#   returns: best [x, y] solution found
def hill_climbing(objective_function, initial_state = np.array([0,0]), step_size = 0.01, print_iters=True):
  # set the starting point of the search algorithm
  current_state = initial_state
  # loop until a peak is found
  i = 0
  while True:
    # Step 1: create a list of neighboring states to the current state
    neighbors = []
    for dx in [-step_size, 0, step_size]:
      for dy in [-step_size, 0, step_size]:
        # skip the current state itself
        if dx == 0 and dy == 0:
          continue
        # create a new state by adding the increments to the current state
        neighbor = current_state + np.array([dx, dy])
        # check if the new state is within the bounds
        if lower_bounds[0] <= neighbor[0] <= upper_bounds[0] and lower_bounds[1] <= neighbor[1] <= upper_bounds[1]:
          # add the new state to the list of neighbors
          neighbors.append(neighbor)
    # Step 2: calculate the objective function at each of the neighboring states
    values = [objective_function(neighbor) for neighbor in neighbors]
    # Step 3: determine the highest-valued neighboring state
    best_index = np.argmax(values)
    best_neighbor = neighbors[best_index]
    best_value = values[best_index]
    # Step 4: compare the highest value among neighboring states to the current value
    #         if the latter is higher, we have found a peak -> return the current state
    #         if the former is higher, assign current state to be the best neighbor state
    current_value = objective_function(current_state)
    if best_value <= current_value:
      return current_state
    else:
      current_state = best_neighbor
    if print_iters:
      print(' Iteration: {}, current_state: {}, current_value:{}'.format(i, current_state, current_value))
    i += 1

# %%
hill_climbing_solution = hill_climbing(objective_function)
print('Hill climbing solution is:', hill_climbing_solution)
# Out:
#  Iteration: 0, current_state: [-0.01 -0.01], current_value:0.9810118431238463
#  Iteration: 1, current_state: [-0.02 -0.02], current_value:1.043242185894391
#  Iteration: 2, current_state: [-0.03 -0.03], current_value:1.106488736553738
#  Iteration: 3, current_state: [-0.04 -0.04], current_value:1.1706625998511844
#  Iteration: 4, current_state: [-0.05 -0.05], current_value:1.2356733918938736
#  Iteration: 5, current_state: [-0.06 -0.06], current_value:1.3014293628501752
#  Iteration: 6, current_state: [-0.07 -0.07], current_value:1.3678375223821952
#  Iteration: 7, current_state: [-0.08 -0.08], current_value:1.4348037678719663
#  Iteration: 8, current_state: [-0.09 -0.09], current_value:1.5022330154933727
#  Iteration: 9, current_state: [-0.1 -0.1], current_value:1.5700293341667775
#  Iteration: 10, current_state: [-0.11 -0.11], current_value:1.6380960824157307
#  Iteration: 11, current_state: [-0.12 -0.12], current_value:1.7063360481252672
#  Iteration: 12, current_state: [-0.13 -0.13], current_value:1.774651591179245
#  Iteration: 13, current_state: [-0.14 -0.14], current_value:1.8429447889301298
#  Iteration: 14, current_state: [-0.15 -0.15], current_value:1.9111175844288848
#  Iteration: 15, current_state: [-0.16 -0.16], current_value:1.9790719373152608
#  Iteration: 16, current_state: [-0.17 -0.17], current_value:2.0467099772402144
#  Iteration: 17, current_state: [-0.18 -0.18], current_value:2.113934159662504
#  Iteration: 18, current_state: [-0.19 -0.19], current_value:2.180647423831155
#  Iteration: 19, current_state: [-0.2 -0.2], current_value:2.246753352734579
#  Iteration: 20, current_state: [-0.21 -0.21], current_value:2.3121563347661036
#  Iteration: 21, current_state: [-0.22 -0.22], current_value:2.376761726824693
#  Iteration: 22, current_state: [-0.23 -0.23], current_value:2.440476018539109
#  Iteration: 23, current_state: [-0.24 -0.24], current_value:2.503206997273889
#  Iteration: 24, current_state: [-0.25 -0.25], current_value:2.5648639135466884
#  Iteration: 25, current_state: [-0.26 -0.26], current_value:2.6253576464589226
#  Iteration: 26, current_state: [-0.27 -0.27], current_value:2.6846008687156413
#  Iteration: 27, current_state: [-0.28 -0.28], current_value:2.7425082107863687
#  Iteration: 28, current_state: [-0.29 -0.29], current_value:2.798996423736508
#  Iteration: 29, current_state: [-0.3 -0.3], current_value:2.853984540239155
#  Iteration: 30, current_state: [-0.31 -0.31], current_value:2.90739403325988
#  Iteration: 31, current_state: [-0.32 -0.32], current_value:2.95914897189257
#  Iteration: 32, current_state: [-0.33 -0.33], current_value:3.0091761738128575
#  Iteration: 33, current_state: [-0.34 -0.34], current_value:3.05740535380719
#  Iteration: 34, current_state: [-0.35 -0.35], current_value:3.1037692678303914
#  Iteration: 35, current_state: [-0.36 -0.36], current_value:3.1482038520426294
#  Iteration: 36, current_state: [-0.37 -0.37], current_value:3.190648356278339
#  Iteration: 37, current_state: [-0.38 -0.38], current_value:3.23104547140459
#  Iteration: 38, current_state: [-0.39 -0.39], current_value:3.2693414500350455
#  Iteration: 39, current_state: [-0.4 -0.4], current_value:3.3054862200776873
#  Iteration: 40, current_state: [-0.4  -0.41], current_value:3.339433490610123
#  Iteration: 41, current_state: [-0.4  -0.42], current_value:3.372850703837291
#  Iteration: 42, current_state: [-0.4  -0.43], current_value:3.405248829139312
#  Iteration: 43, current_state: [-0.4  -0.44], current_value:3.4365634467804513
#  Iteration: 44, current_state: [-0.41 -0.45], current_value:3.4667296115518913
#  Iteration: 45, current_state: [-0.41 -0.46], current_value:3.4961673276241947
#  Iteration: 46, current_state: [-0.41 -0.47], current_value:3.5244112931172595
#  Iteration: 47, current_state: [-0.41 -0.48], current_value:3.5513193043821345
#  Iteration: 48, current_state: [-0.42 -0.49], current_value:3.576825805462597
#  Iteration: 49, current_state: [-0.42 -0.5 ], current_value:3.6013821510846524
#  Iteration: 50, current_state: [-0.42 -0.51], current_value:3.6245029756820166
#  Iteration: 51, current_state: [-0.43 -0.52], current_value:3.646037297207281
#  Iteration: 52, current_state: [-0.43 -0.53], current_value:3.6660103943637297
#  Iteration: 53, current_state: [-0.43 -0.54], current_value:3.6848303313628574
#  Iteration: 54, current_state: [-0.43 -0.55], current_value:3.701885439985339
#  Iteration: 55, current_state: [-0.44 -0.56], current_value:3.7171146927521344
#  Iteration: 56, current_state: [-0.44 -0.57], current_value:3.7309347691725616
#  Iteration: 57, current_state: [-0.44 -0.58], current_value:3.743034663460289
#  Iteration: 58, current_state: [-0.45 -0.59], current_value:3.7531451255278356
#  Iteration: 59, current_state: [-0.45 -0.6 ], current_value:3.761567789572161
#  Iteration: 60, current_state: [-0.45 -0.61], current_value:3.768278895582124
#  Iteration: 61, current_state: [-0.46 -0.62], current_value:3.772852644915758
#  Iteration: 62, current_state: [-0.46 -0.63], current_value:3.7756316536536967
# Hill climbing solution is: [-0.46 -0.63]

# %% [markdown]
# # Part B: Random Restart

# %%
# TODO: Improvement to the Hill-climbing search algorithm using random restarts
#   objective function: function to be maximized
#   lower_bounds: minimum allowable values for the input vector to the objective function 
#   upper_bounds: maximum allowable values for the input vector to the objective function
#   step_size: numerical interval by which to change the current (x,y) state to generate a new neighboring state
#   num_restarts: how many times to restart hill-climbing
#   returns: best [x, y] solution found
def random_restart_hill_climbing(objective_function, lower_bounds, upper_bounds, step_size = 0.001, num_restarts=30):
  best_state = None
  best_value = -float('inf')
  # loop for a given number of restarts
  for i in range(num_restarts):
    # generate a random initial state within the bounds
    initial_state = np.random.uniform(lower_bounds, upper_bounds)
    # perform hill climbing from the initial state
    current_state = hill_climbing(objective_function, initial_state, step_size, print_iters=False)
    # evaluate the current state using the objective function
    current_value = objective_function(current_state)
    # compare the current value with the best value so far
    if current_value > best_value:
      # update the best state and value
      best_state = current_state
      best_value = current_value
    # print the iteration number and state
    print(f" Iteration {i+1}: {current_state}")
  # return the best state found
  return best_state

# %%
random_restart_solution = random_restart_hill_climbing(objective_function, lower_bounds, upper_bounds)
print('Random restart hill climbing solution is:', random_restart_solution)
# Out:
#  Iteration 1: [ 1.28532791 -0.00474635]
#  Iteration 2: [-0.00891919  1.58131696]
#  Iteration 3: [ 1.28545443 -0.00510339]
#  Iteration 4: [-0.00897161  1.58096791]
#  Iteration 5: [ 1.28605579 -0.00489621]
#  Iteration 6: [-0.46030551 -0.62941801]
#  Iteration 7: [ 1.28534061 -0.0046979 ]
#  Iteration 8: [ 1.28541879 -0.00491017]
#  Iteration 9: [-0.45970625 -0.62916621]
#  Iteration 10: [-0.46041796 -0.62953762]
#  Iteration 11: [-0.45969229 -0.6290614 ]
#  Iteration 12: [-0.00888894  1.58122717]
#  Iteration 13: [ 1.28564869 -0.00489413]
#  Iteration 14: [-0.45980486 -0.62872495]
#  Iteration 15: [ 1.28609589 -0.00468792]
#  Iteration 16: [-0.0091231   1.58177558]
#  Iteration 17: [ 1.28546776 -0.0045917 ]
#  Iteration 18: [ 1.28579148 -0.00523232]
#  Iteration 19: [ 1.28573607 -0.00457228]
#  Iteration 20: [-0.45979301 -0.62867336]
#  Iteration 21: [ 1.28577287 -0.00436941]
#  Iteration 22: [-0.00919693  1.58173595]
#  Iteration 23: [ 1.2857483  -0.00440488]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0db74e30c341> in <module>
# ----> 1 random_restart_solution = random_restart_hill_climbing(objective_function, lower_bounds, upper_bounds)
#       2 print('Random restart hill climbing solution is:', random_restart_solution)
#
# <ipython-input-23-8cfcae925317> in random_restart_hill_climbing(objective_function, lower_bounds, upper_bounds, step_size, num_restarts)
#      14     initial_state = np.random.uniform(lower_bounds, upper_bounds)
#      15     # perform hill climbing from the initial state
# ---> 16     current_state = hill_climbing(objective_function, initial_state, step_size, print_iters=False)
#      17     # evaluate the current state using the objective function
#      18     current_value = objective_function(current_state)
#
# <ipython-input-10-388cc06f0802> in hill_climbing(objective_function, initial_state, step_size, print_iters)
#      26           neighbors.append(neighbor)
#      27     # Step 2: calculate the objective function at each of the neighboring states
# ---> 28     values = [objective_function(neighbor) for neighbor in neighbors]
#      29     # Step 3: determine the highest-valued neighboring state
#      30     best_index = np.argmax(values)
#
# <ipython-input-10-388cc06f0802> in <listcomp>(.0)
#      26           neighbors.append(neighbor)
#      27     # Step 2: calculate the objective function at each of the neighboring states
# ---> 28     values = [objective_function(neighbor) for neighbor in neighbors]
#      29     # Step 3: determine the highest-valued neighboring state
#      30     best_index = np.argmax(values)
#
# <ipython-input-6-c16bee2e6394> in objective_function(X)
#       8     y = X[1]
#       9     value = 3 * (1 - x) ** 2 * math.exp(-x ** 2 - (y + 1) ** 2) - 10 * (x / 5 - x ** 3 - y ** 5) * math.exp(
# ---> 10         -x ** 2 - y ** 2) - (1 / 3) * math.exp(-(x + 1) ** 2 - y ** 2)
#      11     return value
#      12
#
# KeyboardInterrupt:

# %% [markdown]
# # Part C: Simulated Annealing

# %%
# TODO: Simulated annealing algorithm
#   objective function: function to be maximized
#   lower_bounds: minimum allowable values for the input vector to the objective function 
#   upper_bounds: maximum allowable values for the input vector to the objective function
#   returns: best [x, y] solution found

def simulated_annealing(objective_function, lower_bounds, upper_bounds):
  # initialize the temperature and cooling rate
  step_size = 0.1
  temperature = 1000
  cooling_rate = 0.99
  # generate a random initial state within the bounds
  current_state = np.random.uniform(lower_bounds, upper_bounds)
  # evaluate the current state using the objective function
  current_value = objective_function(current_state)
  # initialize the best state and value
  best_state = current_state
  best_value = current_value
  iteration = 0 
  # loop until the temperature reaches zero or close to zero
  while temperature > 1e-3:
    # generate a random neighbor state within the bounds by perturbing the current state slightly
    neighbor_state = current_state + np.random.normal(0, step_size)
    neighbor_state = np.clip(neighbor_state, lower_bounds, upper_bounds)
    # evaluate the neighbor state using the objective function
    neighbor_value = objective_function(neighbor_state)
    # calculate the difference between the neighbor value and the current value (delta E in pseudocode)
    delta = neighbor_value - current_value
    # if the neighbor value is better than or equal to the current value, accept it as the new current state (always accept uphill moves in pseudocode)
    if delta >= 0:
      current_state = neighbor_state
      current_value = neighbor_value 
    else:
      probability = np.exp(delta / temperature) 
      if np.random.rand() < probability:
        current_state = neighbor_state 
        current_value = neighbor_value 
    # update the best state and value if needed 
    if current_value > best_value:
      best_state = current_state 
      best_value = current_value 
    # decrease temperature according to cooling schedule (linearly decreasing function in this example) (decrease T according to schedule in pseudocode)
    temperature -= cooling_rate 
    
    print(f"Iteration {iteration}: Current state = {current_state}, Current value = {current_value}")
    iteration +=1
  return best_state

# %%
simulated_annealing_solution = simulated_annealing(objective_function, lower_bounds, upper_bounds)
print('Simulated annealing solution is:', simulated_annealing_solution)
# Out:
# Iteration 0: Current state = [2.07358411 1.99163531], Current value = 0.10239555616775164
# Iteration 1: Current state = [2.01908131 1.93713251], Current value = 0.13970813587161982
# Iteration 2: Current state = [1.95096305 1.86901425], Current value = 0.2017180612853735
# Iteration 3: Current state = [2.00500337 1.92305457], Current value = 0.15101665801362796
# Iteration 4: Current state = [2.0001575  1.91820869], Current value = 0.15508156861812344
# Iteration 5: Current state = [2.11891224 2.03696344], Current value = 0.07819118430594066
# Iteration 6: Current state = [2.09464196 2.01269315], Current value = 0.09045251834734491
# Iteration 7: Current state = [2.03826004 1.95631124], Current value = 0.1254511484918943
# Iteration 8: Current state = [1.90494696 1.82299815], Current value = 0.2550996870368456
# Iteration 9: Current state = [1.8433364 1.7613876], Current value = 0.34342034061295484
# Iteration 10: Current state = [1.81864602 1.73669722], Current value = 0.3847406002650028
# Iteration 11: Current state = [1.83493032 1.75298152], Current value = 0.35709191546811203
# Iteration 12: Current state = [1.8729097 1.7909609], Current value = 0.2984787037704708
# Iteration 13: Current state = [1.72708951 1.64514071], Current value = 0.570142161248811
# Iteration 14: Current state = [1.72645002 1.64450121], Current value = 0.5716211521739615
# Iteration 15: Current state = [1.69115148 1.60920268], Current value = 0.6572567623190183
# Iteration 16: Current state = [1.92205672 1.84010792], Current value = 0.23407037835258673
# Iteration 17: Current state = [2.03305446 1.95110566], Current value = 0.12919395499360986
# Iteration 18: Current state = [1.86818874 1.78623994], Current value = 0.305329837631697
# Iteration 19: Current state = [1.73351753 1.65156873], Current value = 0.5554191973116125
# Iteration 20: Current state = [1.62543416 1.54348536], Current value = 0.8371471254285532
# Iteration 21: Current state = [1.67097268 1.58902387], Current value = 0.7097122458779521
# Iteration 22: Current state = [1.97255509 1.89060629], Current value = 0.18000463707155892
# Iteration 23: Current state = [1.89759498 1.81564618], Current value = 0.2645844649751431
# Iteration 24: Current state = [1.87607513 1.79412633], Current value = 0.29395231818402845
# Iteration 25: Current state = [2.01106328 1.92911448], Current value = 0.14605864192733325
# Iteration 26: Current state = [1.93937149 1.85742268], Current value = 0.2142262907203509
# Iteration 27: Current state = [1.86941005 1.78746124], Current value = 0.30354588036588515
# Iteration 28: Current state = [1.65680132 1.57485252], Current value = 0.7480456534890362
# Iteration 29: Current state = [1.84873201 1.76678321], Current value = 0.33485716169740076
# Iteration 30: Current state = [1.76727164 1.68532284], Current value = 0.48237816042644954
# Iteration 31: Current state = [1.74807829 1.66612949], Current value = 0.5230328376982637
# Iteration 32: Current state = [1.74524718 1.66329838], Current value = 0.5292252381061937
# Iteration 33: Current state = [1.58811107 1.50616227], Current value = 0.9503652397499763
# Iteration 34: Current state = [1.74082889 1.65888009], Current value = 0.5389900524529324
# Iteration 35: Current state = [1.81080631 1.72885751], Current value = 0.39860777896362354
# Iteration 36: Current state = [1.63073314 1.54878434], Current value = 0.8216933841683668
# Iteration 37: Current state = [1.66553797 1.58358917], Current value = 0.7242687159404725
# Iteration 38: Current state = [1.6853484  1.60339959], Current value = 0.6720834569947363
# Iteration 39: Current state = [1.76967361 1.68772481], Current value = 0.477452437792439
# Iteration 40: Current state = [1.85518892 1.77324012], Current value = 0.3248252382919577
# Iteration 41: Current state = [1.87674261 1.79479381], Current value = 0.29300472666954547
# Iteration 42: Current state = [1.92085425 1.83890545], Current value = 0.23550147869882845
# Iteration 43: Current state = [1.86757123 1.78562242], Current value = 0.30623492445630235
# Iteration 44: Current state = [1.80701724 1.72506844], Current value = 0.405441295392433
# Iteration 45: Current state = [1.64683488 1.56488608], Current value = 0.7757297845030977
# Iteration 46: Current state = [1.69884873 1.61689993], Current value = 0.6379150286275707
# Iteration 47: Current state = [1.56812039 1.48617159], Current value = 1.0139448271547766
# Iteration 48: Current state = [1.44990667 1.36795787], Current value = 1.4197494991539539
# Iteration 49: Current state = [1.6004477 1.5184989], Current value = 0.9121207916271576
# Iteration 50: Current state = [1.53758665 1.45563785], Current value = 1.1145287631224334
# Iteration 51: Current state = [1.55622252 1.47427372], Current value = 1.0526683510737411
# Iteration 52: Current state = [1.49975867 1.41780987], Current value = 1.2439376799761643
# Iteration 53: Current state = [1.6121441 1.5301953], Current value = 0.8765999581838579
# Iteration 54: Current state = [1.60255573 1.52060692], Current value = 0.9056649281627298
# Iteration 55: Current state = [1.56804025 1.48609145], Current value = 1.0142035278061157
# Iteration 56: Current state = [1.6117548 1.529806 ], Current value = 0.8777703522875198
# Iteration 57: Current state = [1.79857454 1.71662574], Current value = 0.4209777604462492
# Iteration 58: Current state = [1.81021305 1.72826425], Current value = 0.3996720422839576
# Iteration 59: Current state = [1.77451957 1.69257077], Current value = 0.4676239625387454
# Iteration 60: Current state = [1.76215437 1.68020557], Current value = 0.49299202245361773
# Iteration 61: Current state = [1.94112209 1.85917328], Current value = 0.21229799610049113
# Iteration 62: Current state = [1.99576365 1.91381485], Current value = 0.15884553540087118
# Iteration 63: Current state = [2.12489553 2.04294673], Current value = 0.07539927584621267
# Iteration 64: Current state = [2.24999917 2.16805037], Current value = 0.033861926955439256
# Iteration 65: Current state = [2.01904374 1.93709493], Current value = 0.13973734595078707
# Iteration 66: Current state = [2.00127018 1.91932138], Current value = 0.15414024880882413
# Iteration 67: Current state = [1.95608707 1.87413827], Current value = 0.19638136188994929
# Iteration 68: Current state = [1.85826587 1.77631707], Current value = 0.3201265747390684
# Iteration 69: Current state = [1.8747475 1.7927987], Current value = 0.2958441992914697
# Iteration 70: Current state = [1.7443419  1.66239309], Current value = 0.5312159763510301
# Iteration 71: Current state = [1.7786104 1.6966616], Current value = 0.45944029166779715
# Iteration 72: Current state = [1.64662659 1.56467779], Current value = 0.7763146752493214
# Iteration 73: Current state = [1.67369779 1.59174899], Current value = 0.7024813005876129
# Iteration 74: Current state = [1.79685976 1.71491095], Current value = 0.42418596582778495
# Iteration 75: Current state = [1.74254966 1.66060086], Current value = 0.5351723775784889
# Iteration 76: Current state = [1.61635159 1.53440279], Current value = 0.864003555658956
# Iteration 77: Current state = [1.53712679 1.45517799], Current value = 1.1160726686425182
# Iteration 78: Current state = [1.47266986 1.39072105], Current value = 1.3389752524143672
# Iteration 79: Current state = [1.55696981 1.47502101], Current value = 1.0502178207524293
# Iteration 80: Current state = [1.21774835 1.13579954], Current value = 2.156674605687711
# Iteration 81: Current state = [1.24470738 1.16275857], Current value = 2.0906538894818323
# Iteration 82: Current state = [1.16017822 1.07822942], Current value = 2.267344174366358
# Iteration 83: Current state = [1.24504022 1.16309142], Current value = 2.0897890861130857
# Iteration 84: Current state = [1.37620904 1.29426023], Current value = 1.6805974192561646
# Iteration 85: Current state = [1.45139688 1.36944808], Current value = 1.4144464597518656
# Iteration 86: Current state = [1.366082  1.2841332], Current value = 1.7156317379569614
# Iteration 87: Current state = [1.5488035 1.4668547], Current value = 1.0771257456513306
# Iteration 88: Current state = [1.68918894 1.60724013], Current value = 0.6622475124718545
# Iteration 89: Current state = [1.59030729 1.50835849], Current value = 0.9434997329024316
# Iteration 90: Current state = [1.57490646 1.49295766], Current value = 0.9921471304746959
# Iteration 91: Current state = [1.55870702 1.47675822], Current value = 1.0445304306824978
# Iteration 92: Current state = [1.46423512 1.38228631], Current value = 1.3688371407035491
# Iteration 93: Current state = [1.35292583 1.27097703], Current value = 1.7605950629509157
# Iteration 94: Current state = [1.45952027 1.37757147], Current value = 1.3855685952721404
# Iteration 95: Current state = [1.49009761 1.40814881], Current value = 1.2776527491136
# Iteration 96: Current state = [1.40547552 1.32352672], Current value = 1.5778184793385965
# Iteration 97: Current state = [1.33083901 1.24889021], Current value = 1.8343576521497085
# Iteration 98: Current state = [1.37179736 1.28984855], Current value = 1.6959005611058382
# Iteration 99: Current state = [1.45543302 1.37348422], Current value = 1.400091381510567
# Iteration 100: Current state = [1.45971501 1.3777662 ], Current value = 1.3848770610290804
# Iteration 101: Current state = [1.3382441 1.2562953], Current value = 1.8098958724800773
# Iteration 102: Current state = [1.31388203 1.23193323], Current value = 1.8891994252075028
# Iteration 103: Current state = [1.24223734 1.16028854], Current value = 2.0970353291708896
# Iteration 104: Current state = [1.31194335 1.22999455], Current value = 1.8953561979441478
# Iteration 105: Current state = [1.17904346 1.09709466], Current value = 2.236039810918319
# Iteration 106: Current state = [1.26288192 1.18093312], Current value = 2.041794910743541
# Iteration 107: Current state = [1.33160995 1.24966115], Current value = 1.83182462757738
# Iteration 108: Current state = [1.29428363 1.21233483], Current value = 1.9502480675231904
# Iteration 109: Current state = [1.40465053 1.32270173], Current value = 1.580739040732069
# Iteration 110: Current state = [1.44937405 1.36742525], Current value = 1.4216451997585897
# Iteration 111: Current state = [1.48706047 1.40511167], Current value = 1.288296307663803
# Iteration 112: Current state = [1.28360991 1.2016611 ], Current value = 1.9822962684467422
# Iteration 113: Current state = [1.30869656 1.22674776], Current value = 1.9056116234358254
# Iteration 114: Current state = [1.22989305 1.14794424], Current value = 2.127942640717942
# Iteration 115: Current state = [1.19454027 1.11259146], Current value = 2.206604177541291
# Iteration 116: Current state = [1.43862874 1.35667994], Current value = 1.4599163335264145
# Iteration 117: Current state = [1.44055143 1.35860262], Current value = 1.4530658909251453
# Iteration 118: Current state = [1.52314023 1.44119143], Current value = 1.163398617746706
# Iteration 119: Current state = [1.45932643 1.37737762], Current value = 1.3862569925197374
# Iteration 120: Current state = [1.47364821 1.3916994 ], Current value = 1.3355182729007344
# Iteration 121: Current state = [1.47043119 1.38848238], Current value = 1.3468910937226843
# Iteration 122: Current state = [1.48700359 1.40505479], Current value = 1.2884958538548577
# Iteration 123: Current state = [1.46312993 1.38118113], Current value = 1.3727568307255182
# Iteration 124: Current state = [1.4282826 1.3463338], Current value = 1.4967776526817655
# Iteration 125: Current state = [1.44643067 1.36448187], Current value = 1.43212415228381
# Iteration 126: Current state = [1.39522893 1.31328013], Current value = 1.6140122396646244
# Iteration 127: Current state = [1.19370376 1.11175496], Current value = 2.208275418473757
# Iteration 128: Current state = [1.13934759 1.05739879], Current value = 2.2957784345027217
# Iteration 129: Current state = [1.1353114  1.05336259], Current value = 2.3005118105471407
# Iteration 130: Current state = [1.01687596 0.93492716], Current value = 2.3156133721431558
# Iteration 131: Current state = [0.90883796 0.82688916], Current value = 2.1073423879980404
# Iteration 132: Current state = [0.90535125 0.82340245], Current value = 2.097189661949741
# Iteration 133: Current state = [0.80841867 0.72646987], Current value = 1.741563214993994
# Iteration 134: Current state = [0.65822881 0.57628001], Current value = 1.013517145046312
# Iteration 135: Current state = [0.87911651 0.79716771], Current value = 2.014464936424706
# Iteration 136: Current state = [0.7707013 0.6887525], Current value = 1.5717493539627683
# Iteration 137: Current state = [0.68950431 0.60755551], Current value = 1.1721570215776649
# Iteration 138: Current state = [0.53659271 0.45464391], Current value = 0.4388219717913091
# Iteration 139: Current state = [0.32118008 0.23923128], Current value = -0.04475861543781323
# Iteration 140: Current state = [0.42125277 0.33930396], Current value = 0.0632349643443954
# Iteration 141: Current state = [0.32423849 0.24228969], Current value = -0.04493783924943398
# Iteration 142: Current state = [0.16350193 0.08155312], Current value = 0.27500683352765387
# Iteration 143: Current state = [0.10906627 0.02711747], Current value = 0.5194264290497054
# Iteration 144: Current state = [-0.00545107 -0.08739987], Current value = 1.2064030468634974
# Iteration 145: Current state = [-0.04626559 -0.1282144 ], Current value = 1.4900011720451272
# Iteration 146: Current state = [-0.06370237 -0.14565117], Current value = 1.614558207599476
# Iteration 147: Current state = [-0.00422066 -0.08616946], Current value = 1.198079293826324
# Iteration 148: Current state = [0.10744193 0.02549313], Current value = 0.5276505795865838
# Iteration 149: Current state = [ 0.07480647 -0.00714233], Current value = 0.7032912549815957
# Iteration 150: Current state = [0.2964331 0.2144843], Current value = -0.034882265069606185
# Iteration 151: Current state = [0.27340983 0.19146103], Current value = -0.01212343483564396
# Iteration 152: Current state = [0.19416277 0.11221397], Current value = 0.1659306627339442
# Iteration 153: Current state = [0.34421041 0.26226161], Current value = -0.04054075561417822
# Iteration 154: Current state = [0.26456658 0.18261778], Current value = 0.00010921683560591311
# Iteration 155: Current state = [0.32085798 0.23890917], Current value = -0.044726474807228696
# Iteration 156: Current state = [0.24417984 0.16223104], Current value = 0.035679935021274506
# Iteration 157: Current state = [0.16632209 0.08437329], Current value = 0.2640795124956847
# Iteration 158: Current state = [0.14505103 0.06310223], Current value = 0.35083486907640954
# Iteration 159: Current state = [ 0.08066127 -0.00128753], Current value = 0.6703734323764915
# Iteration 160: Current state = [ 0.00433934 -0.07760946], Current value = 1.140606707120121
# Iteration 161: Current state = [0.1362586 0.0543098], Current value = 0.38955858825525
# Iteration 162: Current state = [0.24995264 0.16800384], Current value = 0.02456640529134474
# Iteration 163: Current state = [0.15014412 0.06819532], Current value = 0.32916054958669705
# Iteration 164: Current state = [0.14160893 0.05966013], Current value = 0.36579889936785814
# Iteration 165: Current state = [0.19699617 0.11504736], Current value = 0.15695017401473405
# Iteration 166: Current state = [0.13684218 0.05489338], Current value = 0.38693768690295655
# Iteration 167: Current state = [0.17630463 0.09435583], Current value = 0.22684126932100088
# Iteration 168: Current state = [0.20577563 0.12382682], Current value = 0.1303285562776808
# Iteration 169: Current state = [0.12178363 0.03983483], Current value = 0.4568287336040354
# Iteration 170: Current state = [0.14539791 0.06344911], Current value = 0.34934092804594363
# Iteration 171: Current state = [ 0.06204573 -0.01990307], Current value = 0.7770386270474792
# Iteration 172: Current state = [ 0.05812619 -0.02382261], Current value = 0.8002226138141325
# Iteration 173: Current state = [ 0.03561055 -0.04633826], Current value = 0.9379322438744666
# Iteration 174: Current state = [ 0.01864879 -0.06330001], Current value = 1.046359300401067
# Iteration 175: Current state = [-0.04259093 -0.12453973], Current value = 1.463961157991477
# Iteration 176: Current state = [ 0.03920074 -0.04274806], Current value = 0.9154783863347654
# Iteration 177: Current state = [ 0.06791515 -0.01403365], Current value = 0.7427835584500696
# Iteration 178: Current state = [0.12315087 0.04120207], Current value = 0.45029105400714525
# Iteration 179: Current state = [0.13938146 0.05743266], Current value = 0.3756170328650644
# Iteration 180: Current state = [0.11282032 0.03087152], Current value = 0.5006158547208346
# Iteration 181: Current state = [0.08280863 0.00085983], Current value = 0.658449422824255
# Iteration 182: Current state = [0.12305465 0.04110584], Current value = 0.4507499248567289
# Iteration 183: Current state = [0.18819182 0.10624302], Current value = 0.1854722341942783
# Iteration 184: Current state = [0.31092826 0.22897946], Current value = -0.04249170849360884
# Iteration 185: Current state = [0.23707713 0.15512832], Current value = 0.050478047413997695
# Iteration 186: Current state = [0.23786637 0.15591757], Current value = 0.04877257101381849
# Iteration 187: Current state = [0.2028236  0.12087479], Current value = 0.1390758288556419
# Iteration 188: Current state = [0.10497815 0.02302935], Current value = 0.5402219616252042
# Iteration 189: Current state = [0.27759521 0.1956464 ], Current value = -0.01723728393444679
# Iteration 190: Current state = [0.24107022 0.15912142], Current value = 0.042006242687372033
# Iteration 191: Current state = [0.21991399 0.13796519], Current value = 0.09132582200300857
# Iteration 192: Current state = [0.38271524 0.30076644], Current value = -0.005405579327896787
# Iteration 193: Current state = [0.45586695 0.37391815], Current value = 0.15125425146294935
# Iteration 194: Current state = [0.49468395 0.41273515], Current value = 0.27653500606634346
# Iteration 195: Current state = [0.61545472 0.53350592], Current value = 0.799876305389137
# Iteration 196: Current state = [0.68676159 0.60481279], Current value = 1.1582501898721869
# Iteration 197: Current state = [0.83913341 0.75718461], Current value = 1.8683274069116704
# Iteration 198: Current state = [0.71706356 0.63511476], Current value = 1.311080596406775
# Iteration 199: Current state = [0.5669493 0.4850005], Current value = 0.5707208435032489
# Iteration 200: Current state = [0.35678694 0.27483814], Current value = -0.032873976982834965
# Iteration 201: Current state = [0.54389703 0.46194823], Current value = 0.46957251574149433
# Iteration 202: Current state = [0.5723658 0.490417 ], Current value = 0.5953113055675766
# Iteration 203: Current state = [0.56439401 0.48244521], Current value = 0.5592228312873201
# Iteration 204: Current state = [0.43712294 0.35517413], Current value = 0.10063880339050914
# Iteration 205: Current state = [0.42498245 0.34303365], Current value = 0.07156261470785247
# Iteration 206: Current state = [0.41184443 0.32989563], Current value = 0.043519155119785984
# Iteration 207: Current state = [0.64154322 0.55959442], Current value = 0.9293946215585275
# Iteration 208: Current state = [0.72017446 0.63822566], Current value = 1.3266208104226958
# Iteration 209: Current state = [0.66775951 0.58581071], Current value = 1.0618124182064475
# Iteration 210: Current state = [0.78599145 0.70404264], Current value = 1.6422480382445086
# Iteration 211: Current state = [0.84255089 0.76060209], Current value = 1.8816960214247465
# Iteration 212: Current state = [0.94143625 0.85948745], Current value = 2.1922480484535507
# Iteration 213: Current state = [1.08170899 0.99976019], Current value = 2.3379469401325763
# Iteration 214: Current state = [1.17349566 1.09154685], Current value = 2.245774355629327
# Iteration 215: Current state = [1.09802707 1.01607827], Current value = 2.331700400756272
# Iteration 216: Current state = [0.94834544 0.86639663], Current value = 2.2078587543613106
# Iteration 217: Current state = [1.05669364 0.97474483], Current value = 2.338387700053769
# Iteration 218: Current state = [0.92756782 0.84561902], Current value = 2.158369687532564
# Iteration 219: Current state = [0.92054408 0.83859528], Current value = 2.1399353662909766
# Iteration 220: Current state = [0.94984272 0.86789392], Current value = 2.211129444556171
# Iteration 221: Current state = [0.77193477 0.68998597], Current value = 1.5775122536550932
# Iteration 222: Current state = [0.8804233 0.7984745], Current value = 2.0188434921454523
# Iteration 223: Current state = [0.82191777 0.73996896], Current value = 1.798689687784811
# Iteration 224: Current state = [0.85990162 0.77795282], Current value = 1.9471034421821114
# Iteration 225: Current state = [0.73902314 0.65707434], Current value = 1.41985657908448
# Iteration 226: Current state = [0.82373095 0.74178215], Current value = 1.8061987007776532
# Iteration 227: Current state = [0.99200401 0.9100552 ], Current value = 2.2865105234103784
# Iteration 228: Current state = [0.72736043 0.64541163], Current value = 1.3623657311272788
# Iteration 229: Current state = [0.71442112 0.63247232], Current value = 1.2978522858149335
# Iteration 230: Current state = [0.52461061 0.4426618 ], Current value = 0.38987003597571734
# Iteration 231: Current state = [0.48460284 0.40265403], Current value = 0.24149945899199332
# Iteration 232: Current state = [0.64964422 0.56769541], Current value = 0.9701488311042541
# Iteration 233: Current state = [0.55088447 0.46893567], Current value = 0.49959705769878343
# Iteration 234: Current state = [0.59169334 0.50974454], Current value = 0.6852753073717488
# Iteration 235: Current state = [0.47936715 0.39741834], Current value = 0.22397335127961737
# Iteration 236: Current state = [0.63779525 0.55584644], Current value = 0.9106098526105846
# Iteration 237: Current state = [0.62990173 0.54795292], Current value = 0.871221903420893
# Iteration 238: Current state = [0.51589677 0.43394796], Current value = 0.35550342909605737
# Iteration 239: Current state = [0.50698243 0.42503362], Current value = 0.3214826898005477
# Iteration 240: Current state = [0.39916253 0.31721373], Current value = 0.01993103297076492
# Iteration 241: Current state = [0.53597207 0.45402326], Current value = 0.4362400942662404
# Iteration 242: Current state = [0.73942207 0.65747326], Current value = 1.4218102598380682
# Iteration 243: Current state = [0.78598458 0.70403577], Current value = 1.6422168405080673
# Iteration 244: Current state = [0.65074917 0.56880037], Current value = 0.9757216549970055
# Iteration 245: Current state = [0.74197065 0.66002185], Current value = 1.4342701154676258
# Iteration 246: Current state = [0.70723124 0.62528244], Current value = 1.261741245435118
# Iteration 247: Current state = [0.69907242 0.61712362], Current value = 1.220589259160577
# Iteration 248: Current state = [0.70016004 0.61821124], Current value = 1.2260840921054004
# Iteration 249: Current state = [0.91343339 0.83148458], Current value = 2.1204132442970396
# Iteration 250: Current state = [0.89138889 0.80944009], Current value = 2.0545335861553355
# Iteration 251: Current state = [0.82222397 0.74027516], Current value = 1.7999605628197692
# Iteration 252: Current state = [0.79493421 0.71298541], Current value = 1.6824696509235122
# Iteration 253: Current state = [0.85380542 0.77185662], Current value = 1.9246018185411902
# Iteration 254: Current state = [0.73725186 0.65530306], Current value = 1.4111711322187923
# Iteration 255: Current state = [0.64829172 0.56634292], Current value = 0.9633317781592058
# Iteration 256: Current state = [0.72021687 0.63826807], Current value = 1.3268324201353783
# Iteration 257: Current state = [0.67744166 0.59549286], Current value = 1.1109529117127082
# Iteration 258: Current state = [0.8491011 0.7671523], Current value = 1.9068795690259386
# Iteration 259: Current state = [0.74214995 0.66020114], Current value = 1.4351452458636689
# Iteration 260: Current state = [0.5511615  0.46921269], Current value = 0.5007992397645075
# Iteration 261: Current state = [0.52482404 0.44287523], Current value = 0.39072510925837367
# Iteration 262: Current state = [0.52239416 0.44044536], Current value = 0.38102735178797825
# Iteration 263: Current state = [0.55706841 0.47511961], Current value = 0.5266412268487156
# Iteration 264: Current state = [0.48553247 0.40358367], Current value = 0.2446598449537532
# Iteration 265: Current state = [0.44154604 0.35959724], Current value = 0.11196675135052497
# Iteration 266: Current state = [0.40241787 0.32046906], Current value = 0.025653917260195697
# Iteration 267: Current state = [0.38462964 0.30268084], Current value = -0.0027672503761564243
# Iteration 268: Current state = [0.32948914 0.24754034], Current value = -0.04471521233099982
# Iteration 269: Current state = [0.18110864 0.09915984], Current value = 0.209730172829132
# Iteration 270: Current state = [0.12744896 0.04550016], Current value = 0.4299865549847933
# Iteration 271: Current state = [0.29553964 0.21359084], Current value = -0.03424372331150342
# Iteration 272: Current state = [0.27282191 0.19087311], Current value = -0.011370316955738813
# Iteration 273: Current state = [0.27639239 0.19444359], Current value = -0.015812099940552313
# Iteration 274: Current state = [0.15368808 0.07173927], Current value = 0.31441075175319255
# Iteration 275: Current state = [0.10327199 0.02132319], Current value = 0.5489957622793746
# Iteration 276: Current state = [ 0.05323785 -0.02871096], Current value = 0.8294751494847181
# Iteration 277: Current state = [0.10813743 0.02618863], Current value = 0.5241229626928221
# Iteration 278: Current state = [0.21561373 0.13366493], Current value = 0.10268023787789891
# Iteration 279: Current state = [0.27237304 0.19042423], Current value = -0.010789546023555738
# Iteration 280: Current state = [0.41300588 0.33105707], Current value = 0.045851992604128956
# Iteration 281: Current state = [0.40619564 0.32424684], Current value = 0.03258388436243462
# Iteration 282: Current state = [0.3193305 0.2373817], Current value = -0.044539600756858075
# Iteration 283: Current state = [0.29425766 0.21230885], Current value = -0.0332930566315809
# Iteration 284: Current state = [0.28989795 0.20794914], Current value = -0.029756009283755325
# Iteration 285: Current state = [0.12670455 0.04475575], Current value = 0.43347618302686225
# Iteration 286: Current state = [0.20648999 0.12454119], Current value = 0.12824297660726994
# Iteration 287: Current state = [ 0.0370416 -0.0449072], Current value = 0.9289605065329483
# Iteration 288: Current state = [-0.00490999 -0.08685879], Current value = 1.2027407294262888
# Iteration 289: Current state = [0.14046428 0.05851548], Current value = 0.3708310696073098
# Iteration 290: Current state = [0.17156515 0.08961635], Current value = 0.2442395145353889
# Iteration 291: Current state = [0.18338979 0.10144099], Current value = 0.20179104398452827
# Iteration 292: Current state = [0.09936787 0.01741906], Current value = 0.5692804239627389
# Iteration 293: Current state = [0.25433924 0.17239044], Current value = 0.01667085735888052
# Iteration 294: Current state = [0.26347843 0.18152963], Current value = 0.0017482739311060619
# Iteration 295: Current state = [0.21484255 0.13289375], Current value = 0.10476360982398589
# Iteration 296: Current state = [0.26924777 0.18729896], Current value = -0.006607531693723745
# Iteration 297: Current state = [0.56903834 0.48708954], Current value = 0.5801703271332177
# Iteration 298: Current state = [0.50363176 0.42168296], Current value = 0.3090037015923461
# Iteration 299: Current state = [0.22774331 0.1457945 ], Current value = 0.07180267305338985
# Iteration 300: Current state = [0.3869093 0.3049605], Current value = 0.0004820760346566505
# Iteration 301: Current state = [0.41813064 0.33618183], Current value = 0.0564861361883828
# Iteration 302: Current state = [0.65030513 0.56835632], Current value = 0.9734817646581378
# Iteration 303: Current state = [0.63950933 0.55756053], Current value = 0.9191947149013171
# Iteration 304: Current state = [0.57548442 0.49353562], Current value = 0.6095995327826599
# Iteration 305: Current state = [0.62443988 0.54249107], Current value = 0.8441255881491113
# Iteration 306: Current state = [0.44971862 0.36776981], Current value = 0.13390487027440007
# Iteration 307: Current state = [0.45011765 0.36816885], Current value = 0.13500904935397848
# Iteration 308: Current state = [0.45302275 0.37107395], Current value = 0.1431394004061386
# Iteration 309: Current state = [0.37602635 0.29407755], Current value = -0.013971968494249615
# Iteration 310: Current state = [0.42763556 0.34568676], Current value = 0.07766102101133907
# Iteration 311: Current state = [0.50113734 0.41918854], Current value = 0.29982585799193734
# Iteration 312: Current state = [0.40338293 0.32143413], Current value = 0.027394841910461445
# Iteration 313: Current state = [0.51792582 0.43597702], Current value = 0.36340968689170017
# Iteration 314: Current state = [0.4088096 0.3268608], Current value = 0.03755918691954222
# Iteration 315: Current state = [0.31843046 0.23648166], Current value = -0.04440282254647907
# Iteration 316: Current state = [0.46614893 0.38420013], Current value = 0.18184567758719686
# Iteration 317: Current state = [0.41437112 0.33242231], Current value = 0.048630762569865905
# Iteration 318: Current state = [0.66104675 0.57909794], Current value = 1.0277837999746384
# Iteration 319: Current state = [0.39229607 0.31034727], Current value = 0.008622210963130678
# Iteration 320: Current state = [0.46466069 0.38271188], Current value = 0.17729766032398517
# Iteration 321: Current state = [0.45497372 0.37302492], Current value = 0.1486893356011898
# Iteration 322: Current state = [0.55947326 0.47752446], Current value = 0.5372734812244188
# Iteration 323: Current state = [0.3701859 0.2882371], Current value = -0.020616005001888107
# Iteration 324: Current state = [0.40264791 0.3206991 ], Current value = 0.026067058814738163
# Iteration 325: Current state = [0.27996842 0.19801962], Current value = -0.019944075175357234
# Iteration 326: Current state = [0.32452203 0.24257323], Current value = -0.044942921687501095
# Iteration 327: Current state = [0.37933185 0.29738305], Current value = -0.009865738795433815
# Iteration 328: Current state = [0.29816837 0.21621957], Current value = -0.03606610416721853
# Iteration 329: Current state = [0.32542776 0.24347896], Current value = -0.044946060683989764
# Iteration 330: Current state = [0.23165183 0.14970303], Current value = 0.06261412158155896
# Iteration 331: Current state = [0.28034315 0.19839435], Current value = -0.02035871487781063
# Iteration 332: Current state = [0.1184258 0.036477 ], Current value = 0.47304453736635554
# Iteration 333: Current state = [0.16779105 0.08584225], Current value = 0.2584583960611547
# Iteration 334: Current state = [ 0.0789995 -0.0029493], Current value = 0.6796562812237356
# Iteration 335: Current state = [0.14094318 0.05899438], Current value = 0.36872230619518676
# Iteration 336: Current state = [0.1801989 0.0982501], Current value = 0.21292982752674194
# Iteration 337: Current state = [0.21818478 0.13623598], Current value = 0.09583797519618194
# Iteration 338: Current state = [0.36517267 0.28322387], Current value = -0.025691678884596836
# Iteration 339: Current state = [0.3811845 0.2992357], Current value = -0.007455608126370805
# Iteration 340: Current state = [0.38606429 0.30411549], Current value = -0.0007359815701589514
# Iteration 341: Current state = [0.43742807 0.35547927], Current value = 0.10140783531632418
# Iteration 342: Current state = [0.63668291 0.55473411], Current value = 0.9050445223098476
# Iteration 343: Current state = [0.5797027 0.4977539], Current value = 0.6290710813598982
# Iteration 344: Current state = [0.6138035  0.53185469], Current value = 0.7917930315766808
# Iteration 345: Current state = [0.70907179 0.62712299], Current value = 1.271000582382319
# Iteration 346: Current state = [0.80410739 0.72215859], Current value = 1.7228818684737386
# Iteration 347: Current state = [0.82999178 0.74804298], Current value = 1.8318158691129611
# Iteration 348: Current state = [0.90688663 0.82493783], Current value = 2.1016853314389192
# Iteration 349: Current state = [0.85644534 0.77449654], Current value = 1.9344109680761024
# Iteration 350: Current state = [0.82697598 0.74502717], Current value = 1.8195370112512401
# Iteration 351: Current state = [0.75081976 0.66887096], Current value = 1.4772262552901443
# Iteration 352: Current state = [0.65194505 0.56999625], Current value = 0.9817564350251892
# Iteration 353: Current state = [0.65780957 0.57586077], Current value = 1.0113957330495074
# Iteration 354: Current state = [0.43682158 0.35487278], Current value = 0.0998811359445127
# Iteration 355: Current state = [0.45846527 0.37651647], Current value = 0.1588003066175468
# Iteration 356: Current state = [0.35198452 0.27003572], Current value = -0.03624375058935794
# Iteration 357: Current state = [0.32636046 0.24441166], Current value = -0.04492845733885692
# Iteration 358: Current state = [0.24789054 0.16594174], Current value = 0.028442020669264156
# Iteration 359: Current state = [0.40769806 0.32574926], Current value = 0.03542557964932589
# Iteration 360: Current state = [0.09862698 0.01667818], Current value = 0.5731622574132027
# Iteration 361: Current state = [ 0.07479281 -0.00715599], Current value = 0.7033687670479263
# Iteration 362: Current state = [ 0.07159464 -0.01035416], Current value = 0.7215982880551871
# Iteration 363: Current state = [-0.07057562 -0.15252442], Current value = 1.6640238345177019
# Iteration 364: Current state = [-0.05008481 -0.13203361], Current value = 1.5171496927224724
# Iteration 365: Current state = [-0.20058163 -0.28253043], Current value = 2.588221090403381
# Iteration 366: Current state = [-0.22862503 -0.31057383], Current value = 2.7712227483450995
# Iteration 367: Current state = [-0.36603064 -0.44797945], Current value = 3.4714222125409746
# Iteration 368: Current state = [-0.20661475 -0.28856355], Current value = 2.6284081834048956
# Iteration 369: Current state = [-0.13968631 -0.22163511], Current value = 2.163976194276629
# Iteration 370: Current state = [-0.19988928 -0.28183808], Current value = 2.5835830101080584
# Iteration 371: Current state = [-0.1390282 -0.220977 ], Current value = 2.1592563277508163
# Iteration 372: Current state = [-0.06326809 -0.1452169 ], Current value = 1.6114388245136968
# Iteration 373: Current state = [-0.17919178 -0.26114058], Current value = 2.4426424378773954
# Iteration 374: Current state = [-0.21957977 -0.30152857], Current value = 2.7132921423688128
# Iteration 375: Current state = [-0.42062169 -0.50257049], Current value = 3.630196441996485
# Iteration 376: Current state = [-0.42831158 -0.51026038], Current value = 3.64629484659571
# Iteration 377: Current state = [-0.42151244 -0.50346124], Current value = 3.632141979577404
# Iteration 378: Current state = [-0.4614506 -0.5433994], Current value = 3.6974828364444603
# Iteration 379: Current state = [-0.5668103 -0.6487591], Current value = 3.665368006030629
# Iteration 380: Current state = [-0.53340862 -0.61535742], Current value = 3.7068900811495196
# Iteration 381: Current state = [-0.4065334  -0.48848221], Current value = 3.596627346003365
# Iteration 382: Current state = [-0.26740339 -0.34935219], Current value = 3.0056871738268374
# Iteration 383: Current state = [-0.39139392 -0.47334273], Current value = 3.5547465987249316
# Iteration 384: Current state = [-0.51266148 -0.59461028], Current value = 3.7183040895477513
# Iteration 385: Current state = [-0.49746744 -0.57941624], Current value = 3.7194679639656205
# Iteration 386: Current state = [-0.57208217 -0.65403097], Current value = 3.656288616030077
# Iteration 387: Current state = [-0.76886691 -0.85081571], Current value = 2.9253651013011988
# Iteration 388: Current state = [-0.82386989 -0.90581869], Current value = 2.6326409282025667
# Iteration 389: Current state = [-0.88071973 -0.96266853], Current value = 2.317784071027245
# Iteration 390: Current state = [-0.94060204 -1.02255084], Current value = 1.9882379865109105
# Iteration 391: Current state = [-1.06131852 -1.14326732], Current value = 1.3826122059051986
# Iteration 392: Current state = [-0.95413957 -1.03608837], Current value = 1.9155011800581476
# Iteration 393: Current state = [-0.89959785 -0.98154665], Current value = 2.212963644813398
# Iteration 394: Current state = [-0.82584826 -0.90779707], Current value = 2.6218078582719797
# Iteration 395: Current state = [-0.73500634 -0.81695515], Current value = 3.0934510119283516
# Iteration 396: Current state = [-0.84721136 -0.92916017], Current value = 2.504035827109238
# Iteration 397: Current state = [-0.84367575 -0.92562455], Current value = 2.523610415384709
# Iteration 398: Current state = [-0.88700581 -0.96895461], Current value = 2.2828333576552713
# Iteration 399: Current state = [-0.77619449 -0.85814329], Current value = 2.887562159338182
# Iteration 400: Current state = [-0.57806458 -0.66001339], Current value = 3.6451756207693244
# Iteration 401: Current state = [-0.56171787 -0.64366667], Current value = 3.673496101636423
# Iteration 402: Current state = [-0.45345812 -0.53540692], Current value = 3.687850947266569
# Iteration 403: Current state = [-0.49129237 -0.57324117], Current value = 3.718180416901708
# Iteration 404: Current state = [-0.53550632 -0.61745512], Current value = 3.7051134696208874
# Iteration 405: Current state = [-0.55077603 -0.63272483], Current value = 3.6887953539495064
# Iteration 406: Current state = [-0.6626454 -0.7445942], Current value = 3.4033434051511398
# Iteration 407: Current state = [-0.52915575 -0.61110455], Current value = 3.7101435445908173
# Iteration 408: Current state = [-0.48414541 -0.56609422], Current value = 3.7154119297463843
# Iteration 409: Current state = [-0.36324848 -0.44519728], Current value = 3.461302320495811
# Iteration 410: Current state = [-0.52325688 -0.60520568], Current value = 3.7138794753730613
# Iteration 411: Current state = [-0.58321252 -0.66516132], Current value = 3.6349319085401803
# Iteration 412: Current state = [-0.6282692  -0.71021801], Current value = 3.519651295241476
# Iteration 413: Current state = [-0.64197511 -0.72392392], Current value = 3.4760212270217585
# Iteration 414: Current state = [-0.78964139 -0.87159019], Current value = 2.817094702564661
# Iteration 415: Current state = [-0.87663793 -0.95858673], Current value = 2.3404926300124713
# Iteration 416: Current state = [-0.85165064 -0.93359944], Current value = 2.479423817862792
# Iteration 417: Current state = [-0.7766435 -0.8585923], Current value = 2.8852313906052878
# Iteration 418: Current state = [-0.81312012 -0.89506893], Current value = 2.6912213656807364
# Iteration 419: Current state = [-0.85953906 -0.94148786], Current value = 2.4356150665248775
# Iteration 420: Current state = [-0.78310224 -0.86505105], Current value = 2.851530156904802
# Iteration 421: Current state = [-0.84537137 -0.92732018], Current value = 2.5142260328378456
# Iteration 422: Current state = [-0.81768906 -0.89963787], Current value = 2.6663846376290876
# Iteration 423: Current state = [-0.82225244 -0.90420124], Current value = 2.6414864027106972
# Iteration 424: Current state = [-0.84013376 -0.92208257], Current value = 2.5431920207115892
# Iteration 425: Current state = [-0.89794496 -0.97989377], Current value = 2.2221205807973985
# Iteration 426: Current state = [-0.77277384 -0.85472264], Current value = 2.9052649991568806
# Iteration 427: Current state = [-0.71075694 -0.79270574], Current value = 3.205782295402648
# Iteration 428: Current state = [-0.5862637 -0.6682125], Current value = 3.628566456532913
# Iteration 429: Current state = [-0.5929915 -0.6749403], Current value = 3.613767000916871
# Iteration 430: Current state = [-0.50104411 -0.58299291], Current value = 3.7197470387555445
# Iteration 431: Current state = [-0.59498641 -0.67693521], Current value = 3.609178692986067
# Iteration 432: Current state = [-0.5467797 -0.6287285], Current value = 3.693637295001319
# Iteration 433: Current state = [-0.33210287 -0.41405167], Current value = 3.335317822475602
# Iteration 434: Current state = [-0.31670761 -0.39865642], Current value = 3.264784606755755
# Iteration 435: Current state = [-0.45892664 -0.54087544], Current value = 3.69462794398304
# Iteration 436: Current state = [-0.28782207 -0.36977088], Current value = 3.118791850157144
# Iteration 437: Current state = [-0.17770459 -0.25965339], Current value = 2.4323585103389687
# Iteration 438: Current state = [-0.16423613 -0.24618493], Current value = 2.3383972957395938
# Iteration 439: Current state = [-0.27683542 -0.35878423], Current value = 3.0588963899543664
# Iteration 440: Current state = [-0.08352645 -0.16547525], Current value = 1.7576206524983387
# Iteration 441: Current state = [-0.02931065 -0.11125945], Current value = 1.3705961125357171
# Iteration 442: Current state = [0.09216583 0.01021703], Current value = 0.6074479415025067
# Iteration 443: Current state = [-0.1044261 -0.1863749], Current value = 1.9092156744459934
# Iteration 444: Current state = [-0.17208797 -0.25403678], Current value = 2.3933501578131624
# Iteration 445: Current state = [-0.09817279 -0.18012159], Current value = 1.8638327633963077
# Iteration 446: Current state = [-0.17089619 -0.25284499], Current value = 2.385039727317804
# Iteration 447: Current state = [-0.18356105 -0.26550985], Current value = 2.472741827385904
# Iteration 448: Current state = [-0.29726015 -0.37920896], Current value = 3.168373365771326
# Iteration 449: Current state = [-0.33440972 -0.41635852], Current value = 3.3454282487359768
# Iteration 450: Current state = [-0.24201962 -0.32396842], Current value = 2.854881169310323
# Iteration 451: Current state = [-0.33279547 -0.41474427], Current value = 3.338366102274083
# Iteration 452: Current state = [-0.36767862 -0.44962742], Current value = 3.477326568791539
# Iteration 453: Current state = [-0.50316365 -0.58511245], Current value = 3.7197513173783703
# Iteration 454: Current state = [-0.49057501 -0.57252381], Current value = 3.7179645394029324
# Iteration 455: Current state = [-0.41151936 -0.49346816], Current value = 3.609107617136091
# Iteration 456: Current state = [-0.40172072 -0.48366952], Current value = 3.583961460295705
# Iteration 457: Current state = [-0.43152367 -0.51347247], Current value = 3.652550923265436
# Iteration 458: Current state = [-0.53826612 -0.62021492], Current value = 3.702603886191262
# Iteration 459: Current state = [-0.42996757 -0.51191637], Current value = 3.649554685875304
# Iteration 460: Current state = [-0.47712813 -0.55907694], Current value = 3.711354803170174
# Iteration 461: Current state = [-0.4952898 -0.5772386], Current value = 3.7191305315552805
# Iteration 462: Current state = [-0.43253754 -0.51448635], Current value = 3.654468160672465
# Iteration 463: Current state = [-0.41381813 -0.49576693], Current value = 3.614640757324687
# Iteration 464: Current state = [-0.48700897 -0.56895778], Current value = 3.7166861605489747
# Iteration 465: Current state = [-0.45745162 -0.53940042], Current value = 3.692879695462571
# Iteration 466: Current state = [-0.4368927 -0.5188415], Current value = 3.6623897599412096
# Iteration 467: Current state = [-0.51223739 -0.59418619], Current value = 3.718419684934409
# Iteration 468: Current state = [-0.55508208 -0.63703089], Current value = 3.6831297247535253
# Iteration 469: Current state = [-0.53062692 -0.61257572], Current value = 3.7090710077704885
# Iteration 470: Current state = [-0.39706744 -0.47901624], Current value = 3.5711397876976227
# Iteration 471: Current state = [-0.40141022 -0.48335902], Current value = 3.5831234689422504
# Iteration 472: Current state = [-0.19983354 -0.28178234], Current value = 2.583209343433716
# Iteration 473: Current state = [-0.3248575 -0.4068063], Current value = 3.302779783462699
# Iteration 474: Current state = [-0.20645026 -0.28839907], Current value = 2.6273180876995252
# Iteration 475: Current state = [-0.14685475 -0.22880355], Current value = 2.215255893064648
# Iteration 476: Current state = [-0.18190028 -0.26384909], Current value = 2.4613214005902515
# Iteration 477: Current state = [-0.18320987 -0.26515868], Current value = 2.4703290650382432
# Iteration 478: Current state = [-0.17004859 -0.25199739], Current value = 2.3791225389094426
# Iteration 479: Current state = [-0.14539487 -0.22734367], Current value = 2.204833069628642
# Iteration 480: Current state = [-0.22229209 -0.30424089], Current value = 2.730779209861102
# Iteration 481: Current state = [-0.22848602 -0.31043483], Current value = 2.770340957207549
# Iteration 482: Current state = [-0.17585055 -0.25779935], Current value = 2.41951111739295
# Iteration 483: Current state = [ 0.0011081 -0.0808407], Current value = 1.162210188583742
# Iteration 484: Current state = [0.14766763 0.06571882], Current value = 0.339629652326626
# Iteration 485: Current state = [0.19691842 0.11496961], Current value = 0.15719408108296712
# Iteration 486: Current state = [0.1693468 0.087398 ], Current value = 0.25255813332474963
# Iteration 487: Current state = [0.2790636 0.1971148], Current value = -0.018928541820962444
# Iteration 488: Current state = [0.23894257 0.15699377], Current value = 0.0464716256934882
# Iteration 489: Current state = [0.29580408 0.21385528], Current value = -0.034434771549966534
# Iteration 490: Current state = [0.47411973 0.39217092], Current value = 0.20688085944511833
# Iteration 491: Current state = [0.48981906 0.40787026], Current value = 0.2594189714001603
# Iteration 492: Current state = [0.57676246 0.49481366], Current value = 0.6154815591266913
# Iteration 493: Current state = [0.52887872 0.44692992], Current value = 0.40708775565696087
# Iteration 494: Current state = [0.58064947 0.49870067], Current value = 0.6334637159199635
# Iteration 495: Current state = [0.5791864 0.4972376], Current value = 0.6266790674356387
# Iteration 496: Current state = [0.66147801 0.57952921], Current value = 1.029968300864317
# Iteration 497: Current state = [0.64467713 0.56272833], Current value = 0.9451375889641299
# Iteration 498: Current state = [0.55513654 0.47318774], Current value = 0.5181462811967223
# Iteration 499: Current state = [0.57061947 0.48867067], Current value = 0.5873513680030291
# Iteration 500: Current state = [0.6219216 0.5399728], Current value = 0.8316808733403129
# Iteration 501: Current state = [0.66894822 0.58699942], Current value = 1.0678430200839177
# Iteration 502: Current state = [0.71225728 0.63030848], Current value = 1.2870017485145286
# Iteration 503: Current state = [0.77348979 0.69154098], Current value = 1.5847592225990677
# Iteration 504: Current state = [0.74322499 0.66127619], Current value = 1.440388499784953
# Iteration 505: Current state = [0.81051223 0.72856343], Current value = 1.7505604607651208
# Iteration 506: Current state = [0.85663785 0.77468904], Current value = 1.935122398202465
# Iteration 507: Current state = [0.86499713 0.78304833], Current value = 1.965500900719412
# Iteration 508: Current state = [0.6298279 0.5478791], Current value = 0.8708547272565532
# Iteration 509: Current state = [0.61743984 0.53549104], Current value = 0.809614806719791
# Iteration 510: Current state = [0.71423281 0.632284  ], Current value = 1.296908620853804
# Iteration 511: Current state = [0.74691827 0.66496946], Current value = 1.4583480002854308
# Iteration 512: Current state = [0.79417529 0.71222649], Current value = 1.6790871204051703
# Iteration 513: Current state = [0.87313314 0.79118434], Current value = 1.9940824384311575
# Iteration 514: Current state = [0.82865277 0.74670397], Current value = 1.8263781465492697
# Iteration 515: Current state = [0.89025749 0.80830869], Current value = 2.050939076418521
# Iteration 516: Current state = [0.96255787 0.88060906], Current value = 2.237278469432195
# Iteration 517: Current state = [0.97236661 0.89041781], Current value = 2.255445715772979
# Iteration 518: Current state = [0.95126343 0.86931463], Current value = 2.2141957300081825
# Iteration 519: Current state = [0.87262433 0.79067553], Current value = 1.9923240393586454
# Iteration 520: Current state = [0.96091289 0.87896409], Current value = 2.23406016399571
# Iteration 521: Current state = [0.97614799 0.89419919], Current value = 2.261979437584954
# Iteration 522: Current state = [0.97558107 0.89363227], Current value = 2.261016601491626
# Iteration 523: Current state = [0.7119395 0.6299907], Current value = 1.285406973709397
# Iteration 524: Current state = [0.68047128 0.59852248], Current value = 1.126332068003253
# ...
# Iteration 845: Current state = [-2.28871878 -2.37066758], Current value = 0.0094635969453428
# Iteration 846: Current state = [-2.21060998 -2.29255879], Current value = 0.014484442726111043
# Iteration 847: Current state = [-2.32835707 -2.41030587], Current value = 0.00753844547923606
# Iteration 848: Current state = [-2.44513974 -2.52708854], Current value = 0.0036859324772027047
# Iteration 849: Current state = [-2.78234693 -2.86429574], Current value = 0.0003191380014228523
# Iteration 850: Current state = [-2.76040156 -2.84235037], Current value = 0.0003806446355357352
# Iteration 851: Current state = [-2.78439091 -2.86633971], Current value = 0.0003139047192258551
# Iteration 852: Current state = [-2.90886549 -2.9908143 ], Current value = 0.00011041193255287148
# Iteration 853: Current state = [-2.85966635 -2.94161516], Current value = 0.0001683605056078241
# Iteration 854: Current state = [-2.79350102 -2.87544982], Current value = 0.00029153200759288086
# Iteration 855: Current state = [-2.67547078 -2.75741959], Current value = 0.0007364270276133118
# Iteration 856: Current state = [-2.80103471 -2.88298351], Current value = 0.0002741570260595183
# Iteration 857: Current state = [-2.80117463 -2.88312344], Current value = 0.00027384360355061786
# Iteration 858: Current state = [-2.58065282 -2.66260163], Current value = 0.001475403064859456
# Iteration 859: Current state = [-2.84022273 -2.92217153], Current value = 0.00019827205778611169
# Iteration 860: Current state = [-2.90426389 -2.98621269], Current value = 0.00011491216829577476
# Iteration 861: Current state = [-2.91045241 -2.99240122], Current value = 0.0001088986449105924
# Iteration 862: Current state = [-3.08941693 -3.17136573], Current value = 2.1276978755348176e-05
# Iteration 863: Current state = [-3.02250887 -3.10445767], Current value = 3.987345049196694e-05
# Iteration 864: Current state = [-3.1290454 -3.2109942], Current value = 1.4523647798090204e-05
# Iteration 865: Current state = [-3.09784867 -3.17979748], Current value = 1.9628673288301026e-05
# Iteration 866: Current state = [-3.0139803 -3.0959291], Current value = 4.3131921782859505e-05
# Iteration 867: Current state = [-2.93041551 -3.01236431], Current value = 9.144924216182932e-05
# Iteration 868: Current state = [-2.95125127 -3.03320007], Current value = 7.60579539460033e-05
# Iteration 869: Current state = [-2.87107093 -2.95301973], Current value = 0.00015283264664360828
# Iteration 870: Current state = [-2.82981524 -2.91176404], Current value = 0.0002162480380496035
# Iteration 871: Current state = [-2.86012493 -2.94207374], Current value = 0.00016770872278918652
# Iteration 872: Current state = [-2.97704784 -3.05899664], Current value = 6.036914637029853e-05
# Iteration 873: Current state = [-2.9077024  -2.98965121], Current value = 0.00011153354277665631
# Iteration 874: Current state = [-2.91926964 -3.00121844], Current value = 0.00010083848726851223
# Iteration 875: Current state = [-2.89574119 -2.97768999], Current value = 0.0001237041665220879
# Iteration 876: Current state = [-2.93031001 -3.01225882], Current value = 9.153412872993002e-05
# Iteration 877: Current state = [-3.14816388 -3.23011268], Current value = 1.2048660311692535e-05
# Iteration 878: Current state = [-3.09982498 -3.18177378], Current value = 1.926025724740866e-05
# Iteration 879: Current state = [-3.14493694 -3.22688574], Current value = 1.2436125968185665e-05
# Iteration 880: Current state = [-3.03393053 -3.11587933], Current value = 3.587267782811943e-05
# Iteration 881: Current state = [-2.92977523 -3.01172404], Current value = 9.196559299070632e-05
# Iteration 882: Current state = [-2.82925927 -2.91120807], Current value = 0.0002172497315667787
# Iteration 883: Current state = [-2.81447238 -2.89642118], Current value = 0.0002455289475509661
# Iteration 884: Current state = [-2.77864763 -2.86059643], Current value = 0.00032881539983886177
# Iteration 885: Current state = [-2.70471962 -2.78666843], Current value = 0.0005890551022525624
# Iteration 886: Current state = [-2.98363435 -3.06558315], Current value = 5.6882583622357577e-05
# Iteration 887: Current state = [-3.00610857 -3.08805737], Current value = 4.6361191271866305e-05
# Iteration 888: Current state = [-3.07495811 -3.15690691], Current value = 2.4413271965220985e-05
# Iteration 889: Current state = [-2.71802253 -2.79997133], Current value = 0.0005314324206353182
# Iteration 890: Current state = [-2.61018862 -2.69213742], Current value = 0.0011939216821293698
# Iteration 891: Current state = [-2.61463374 -2.69658254], Current value = 0.0011560516041340344
# Iteration 892: Current state = [-2.65803646 -2.73998526], Current value = 0.0008395847683060497
# Iteration 893: Current state = [-2.63116532 -2.71311413], Current value = 0.0010245739385193289
# Iteration 894: Current state = [-2.63007436 -2.71202316], Current value = 0.0010328128567932344
# Iteration 895: Current state = [-2.66383084 -2.74577965], Current value = 0.0008039222346728556
# Iteration 896: Current state = [-2.61217145 -2.69412025], Current value = 0.0011768923359867893
# Iteration 897: Current state = [-2.72545975 -2.80740855], Current value = 0.0005015214402069359
# Iteration 898: Current state = [-2.66835956 -2.75030836], Current value = 0.0007770180194168537
# Iteration 899: Current state = [-2.89181035 -2.97375915], Current value = 0.00012796789858396447
# Iteration 900: Current state = [-2.98639183 -3.06834063], Current value = 5.54800229801723e-05
# Iteration 901: Current state = [-3.09432975 -3.17627855], Current value = 2.0301275835732884e-05
# Iteration 902: Current state = [-3.06549816 -3.14744697], Current value = 2.669728360445725e-05
# Iteration 903: Current state = [-3.24478746 -3.32673626], Current value = 4.567548165392169e-06
# Iteration 904: Current state = [-3.22557811 -3.30752691], Current value = 5.557944378508428e-06
# Iteration 905: Current state = [-3.18632086 -3.26826966], Current value = 8.256795912523283e-06
# Iteration 906: Current state = [-3.22674487 -3.30869367], Current value = 5.492350649273784e-06
# Iteration 907: Current state = [-3.20675767 -3.28870647], Current value = 6.725237117167714e-06
# Iteration 908: Current state = [-3.08883907 -3.17078788], Current value = 2.1394624299153805e-05
# Iteration 909: Current state = [-3.14413393 -3.22608273], Current value = 1.2534372713609839e-05
# Iteration 910: Current state = [-3.23850674 -3.32045554], Current value = 4.8711454621972805e-06
# Iteration 911: Current state = [-3.17593629 -3.25788509], Current value = 9.157317003955979e-06
# Iteration 912: Current state = [-3.33460797 -3.41655677], Current value = 1.7842553115483814e-06
# Iteration 913: Current state = [-3.3857356 -3.4676844], Current value = 1.0279999040482307e-06
# Iteration 914: Current state = [-3.34513648 -3.42708528], Current value = 1.594279214977937e-06
# Iteration 915: Current state = [-3.35725936 -3.43920816], Current value = 1.399581493009647e-06
# Iteration 916: Current state = [-3.27871303 -3.36066183], Current value = 3.2163867114963876e-06
# Iteration 917: Current state = [-3.26782014 -3.34976894], Current value = 3.601823028608103e-06
# Iteration 918: Current state = [-3.48938819 -3.57133699], Current value = 3.24237223066316e-07
# Iteration 919: Current state = [-3.6421935 -3.7241423], Current value = 5.42280918622358e-08
# Iteration 920: Current state = [-3.38790592 -3.46985472], Current value = 1.0039562493775777e-06
# Iteration 921: Current state = [-3.44031273 -3.52226153], Current value = 5.632915620879686e-07
# Iteration 922: Current state = [-3.41643879 -3.4983876 ], Current value = 7.340606867820451e-07
# Iteration 923: Current state = [-3.37885616 -3.46080496], Current value = 1.1079296739492209e-06
# Iteration 924: Current state = [-3.39302464 -3.47497344], Current value = 9.493729712641917e-07
# Iteration 925: Current state = [-3.26779077 -3.34973957], Current value = 3.6029196879909047e-06
# Iteration 926: Current state = [-3.35116456 -3.43311336], Current value = 1.4944210574957081e-06
# Iteration 927: Current state = [-3.29596838 -3.37791718], Current value = 2.6854890513012677e-06
# Iteration 928: Current state = [-3.31743849 -3.3993873 ], Current value = 2.1415171568854393e-06
# Iteration 929: Current state = [-3.39242759 -3.47437639], Current value = 9.55589330487569e-07
# Iteration 930: Current state = [-3.5012046 -3.5831534], Current value = 2.834063856189795e-07
# Iteration 931: Current state = [-3.51393038 -3.59587919], Current value = 2.4499434168719634e-07
# Iteration 932: Current state = [-3.53402296 -3.61597176], Current value = 1.943789714355613e-07
# Iteration 933: Current state = [-3.52001263 -3.60196143], Current value = 2.2846187164616086e-07
# Iteration 934: Current state = [-3.67833295 -3.76028175], Current value = 3.499480070380522e-08
# Iteration 935: Current state = [-3.66612158 -3.74807039], Current value = 4.0602877616664424e-08
# Iteration 936: Current state = [-3.70796684 -3.78991565], Current value = 2.433152348585249e-08
# Iteration 937: Current state = [-3.76143778 -3.84338658], Current value = 1.2507155085722349e-08
# Iteration 938: Current state = [-3.70042299 -3.78237179], Current value = 2.669975848286306e-08
# Iteration 939: Current state = [-3.76729159 -3.84924039], Current value = 1.1619564422004033e-08
# Iteration 940: Current state = [-3.70283991 -3.78478871], Current value = 2.5917642628760616e-08
# Iteration 941: Current state = [-3.77321713 -3.85516593], Current value = 1.0783592421082385e-08
# Iteration 942: Current state = [-3.88606437 -3.96801318], Current value = 2.5269493782419405e-09
# Iteration 943: Current state = [-3.91989454 -4.        ], Current value = 1.6357416062056565e-09
# Iteration 944: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 945: Current state = [-3.9782743 -3.9782743], Current value = 1.202413773716539e-09
# Iteration 946: Current state = [-3.94095035 -3.94095035], Current value = 1.9711978390698642e-09
# Iteration 947: Current state = [-3.74617803 -3.74617803], Current value = 2.357955890957148e-08
# Iteration 948: Current state = [-3.83446556 -3.83446556], Current value = 7.813442967985522e-09
# Iteration 949: Current state = [-3.75869826 -3.75869826], Current value = 2.0202607473496364e-08
# Iteration 950: Current state = [-3.62227006 -3.62227006], Current value = 1.0490346577196698e-07
# Iteration 951: Current state = [-3.66164977 -3.66164977], Current value = 6.575695424930606e-08
# Iteration 952: Current state = [-3.67238311 -3.67238311], Current value = 5.7828121771992924e-08
# Iteration 953: Current state = [-3.6165526 -3.6165526], Current value = 1.1220031636749366e-07
# Iteration 954: Current state = [-3.56860756 -3.56860756], Current value = 1.9607510999036764e-07
# Iteration 955: Current state = [-3.55724502 -3.55724502], Current value = 2.234742984909486e-07
# Iteration 956: Current state = [-3.62151836 -3.62151836], Current value = 1.0583590638105877e-07
# Iteration 957: Current state = [-3.67530139 -3.67530139], Current value = 5.583788306331753e-08
# Iteration 958: Current state = [-3.87327756 -3.87327756], Current value = 4.756728011139017e-09
# Iteration 959: Current state = [-3.98674779 -3.98674779], Current value = 1.0738765446215848e-09
# Iteration 960: Current state = [-3.98519651 -3.98519651], Current value = 1.096360222739247e-09
# Iteration 961: Current state = [-3.84197801 -3.84197801], Current value = 7.101419445772501e-09
# Iteration 962: Current state = [-3.7656575 -3.7656575], Current value = 1.8533878768217918e-08
# Iteration 963: Current state = [-3.73379532 -3.73379532], Current value = 2.7455791242445695e-08
# Iteration 964: Current state = [-3.80272689 -3.80272689], Current value = 1.1667707543369783e-08
# Iteration 965: Current state = [-3.82488986 -3.82488986], Current value = 8.822313752424218e-09
# Iteration 966: Current state = [-3.73980983 -3.73980983], Current value = 2.5501468497517065e-08
# Iteration 967: Current state = [-3.8420473 -3.8420473], Current value = 7.095155317254211e-09
# Iteration 968: Current state = [-3.73054471 -3.73054471], Current value = 2.8571781341170702e-08
# Iteration 969: Current state = [-3.72999628 -3.72999628], Current value = 2.8764360461098923e-08
# Iteration 970: Current state = [-3.55513598 -3.55513598], Current value = 2.2895178461342058e-07
# Iteration 971: Current state = [-3.62577461 -3.62577461], Current value = 1.006602447580391e-07
# Iteration 972: Current state = [-3.72168072 -3.72168072], Current value = 3.184338537340842e-08
# Iteration 973: Current state = [-3.7284063 -3.7284063], Current value = 2.9329816182161707e-08
# Iteration 974: Current state = [-3.7037783 -3.7037783], Current value = 3.9596234379983554e-08
# Iteration 975: Current state = [-3.71435226 -3.71435226], Current value = 3.4820274701358465e-08
# Iteration 976: Current state = [-3.72439313 -3.72439313], Current value = 3.080547225633627e-08
# Iteration 977: Current state = [-3.72625567 -3.72625567], Current value = 3.011186210804035e-08
# Iteration 978: Current state = [-3.9151769 -3.9151769], Current value = 2.7634368588340742e-09
# Iteration 979: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 980: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 981: Current state = [-3.91272091 -3.91272091], Current value = 2.853419706077855e-09
# Iteration 982: Current state = [-3.92524563 -3.92524563], Current value = 2.4225897830040783e-09
# Iteration 983: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 984: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 985: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 986: Current state = [-4. -4.], Current value = 8.99281667400895e-10
# Iteration 987: Current state = [-3.74690697 -3.74690697], Current value = 2.3368753540863376e-08
# Iteration 988: Current state = [-3.63731191 -3.63731191], Current value = 8.783312885443164e-08
# Iteration 989: Current state = [-3.55910658 -3.55910658], Current value = 2.187449716312902e-07
# Iteration 990: Current state = [-3.53021755 -3.53021755], Current value = 3.043312156047312e-07
# Iteration 991: Current state = [-3.53307268 -3.53307268], Current value = 2.946083354983104e-07
# Iteration 992: Current state = [-3.47823454 -3.47823454], Current value = 5.46174545667163e-07
# Iteration 993: Current state = [-3.25828376 -3.25828376], Current value = 5.670373654149655e-06
# Iteration 994: Current state = [-3.29158762 -3.29158762], Current value = 4.035033071531592e-06
# Iteration 995: Current state = [-3.21011848 -3.21011848], Current value = 9.192162369621425e-06
# Iteration 996: Current state = [-3.16089191 -3.16089191], Current value = 1.489577435144798e-05
# Iteration 997: Current state = [-3.21728045 -3.21728045], Current value = 8.560770239114064e-06
# Iteration 998: Current state = [-3.18331569 -3.18331569], Current value = 1.1971990499971417e-05
# Iteration 999: Current state = [-3.1830389 -3.1830389], Current value = 1.200449405447273e-05
# Iteration 1000: Current state = [-3.2335871 -3.2335871], Current value = 7.273879115619165e-06
# Iteration 1001: Current state = [-3.29627162 -3.29627162], Current value = 3.844932486079304e-06
# Iteration 1002: Current state = [-3.09790716 -3.09790716], Current value = 2.7177399277797986e-05
# Iteration 1003: Current state = [-2.91273014 -2.91273014], Current value = 0.00014299848871488996
# Iteration 1004: Current state = [-2.79275031 -2.79275031], Current value = 0.0003844751300182191
# Iteration 1005: Current state = [-2.87503711 -2.87503711], Current value = 0.00019656005212705484
# Iteration 1006: Current state = [-2.80997338 -2.80997338], Current value = 0.00033500396684656587
# Iteration 1007: Current state = [-2.81771245 -2.81771245], Current value = 0.0003147525704531391
# Iteration 1008: Current state = [-2.84297068 -2.84297068], Current value = 0.00025628118295434717
# Iteration 1009: Current state = [-2.87145501 -2.87145501], Current value = 0.00020252208491863038
# Iteration 1010: Current state = [-2.79236092 -2.79236092], Current value = 0.00038566789958625045
# Simulated annealing solution is: [-0.50316365 -0.58511245]
